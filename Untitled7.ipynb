# %% [markdown]
# <a href="https://colab.research.google.com/github/shriharish123/DAA-lab-exercise/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_optimal_parens(s, i, j):
    """Generates optimal parenthesization string"""
    if i == j:
        return f"A{i}"

    left = print_optimal_parens(s, i, s[i][j])
    right = print_optimal_parens(s, s[i][j] + 1, j)
    return f"({left}{right})"

def print_dp_table(m, n):
    """Prints the DP cost table nicely"""
    print("\nDP Table (Cost Matrix):")
    for i in range(1, n + 1):
        row = []
        for j in range(1, n + 1):
            if j >= i:
                row.append(f"{m[i][j]:>7}")
            else:
                row.append("      -")
        print(f"Row {i}: " + " ".join(row))

def matrix_chain_order(dims):
    """
    Matrix Chain Multiplication using DP
    dims: list of dimensions, matrix i has dims[i-1] x dims[i]
    Time: O(n^3), Space: O(n^2)
    """
    n = len(dims) - 1
    # m[i][j] = minimum multiplications for matrices i..j
    m = [[0] * (n + 1) for _ in range(n + 1)]
    s = [[0] * (n + 1) for _ in range(n + 1)]

    # l is the chain length
    for l in range(2, n + 1):
        for i in range(1, n - l + 2):
            j = i + l - 1
            m[i][j] = float('inf')
            for k in range(i, j):
                cost = m[i][k] + m[k+1][j] + dims[i-1] * dims[k] * dims[j]
                if cost < m[i][j]:
                    m[i][j] = cost
                    s[i][j] = k

    return m, s

# --- Execution ---
dims = [10, 30, 5, 60, 10]
n = len(dims) - 1

print('Matrix Dimensions:')
for i in range(n):
    print(f' A{i+1}: {dims[i]} x {dims[i+1]}')

m, s = matrix_chain_order(dims)

print(f'\nMinimum scalar multiplications: {m[1][n]}')
print(f'Optimal parenthesization: {print_optimal_parens(s, 1, n)}')
print_dp_table(m, n)
# Out:
# Matrix Dimensions:
#  A1: 10 x 30
#  A2: 30 x 5
#  A3: 5 x 60
#  A4: 60 x 10
#
# Minimum scalar multiplications: 5000
# Optimal parenthesization: ((A1A2)(A3A4))
#
# DP Table (Cost Matrix):
# Row 1:       0    1500    4500    5000
# Row 2:       -       0    9000    4500
# Row 3:       -       -       0    3000
# Row 4:       -       -       -       0
